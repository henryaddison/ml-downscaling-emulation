# %%
import cftime
import xarray

# %%
input = xarray.load_dataset("../../../../data/60km/rcp85/01/pr/day/pr_rcp85_land-gcm_uk_60km_01_day_19791201-19891130.nc")
input.encoding["time"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-f1b5efb2f5fb> in <module>
#       1 input = xarray.load_dataset("../../../../data/60km/rcp85/01/pr/day/pr_rcp85_land-gcm_uk_60km_01_day_19791201-19891130.nc")
# ----> 2 input.encoding["time"]
#
# KeyError: 'time'

# %%
year = 1980

# %%
# single_year_input = inputsingle_year_input = input.loc[dict(time=slice("1980-12-01", "1981-11-30"))]
single_year_input = input.isel(time=slice(360,720))

single_year_input
# Out:
# <xarray.Dataset>
# Dimensions:                       (bnds: 2, ensemble_member: 1, projection_x_coordinate: 17, projection_y_coordinate: 23, time: 360)
# Coordinates:
#   * ensemble_member               (ensemble_member) int32 1
#   * time                          (time) object 1980-12-01 12:00:00 ... 1981-...
#   * projection_y_coordinate       (projection_y_coordinate) float64 -9e+04 .....
#   * projection_x_coordinate       (projection_x_coordinate) float64 -2.1e+05 ...
#     ensemble_member_id            (ensemble_member) |S27 b'HadGEM3-GC3.05-r00...
#     latitude                      (projection_y_coordinate, projection_x_coordinate) float64 ...
#     longitude                     (projection_y_coordinate, projection_x_coordinate) float64 ...
#     month_number                  (time) int32 12 12 12 12 12 ... 11 11 11 11 11
#     year                          (time) int32 1980 1980 1980 ... 1981 1981 1981
# ...

# %%
output_filepath = f"../../../../derived_data/60km/rcp85/01/pr/day/pr_rcp85_land-gcm_uk_60km_01_day_{year}1201-{year+1}1130.nc"
single_year_input.to_netcdf(output_filepath)

# %%
iris.load_cube(output_filepath)
# Out:
# <iris 'Cube' of lwe_precipitation_rate / (mm/day) (ensemble_member: 1; time: 360; projection_y_coordinate: 23; projection_x_coordinate: 17)>

# %%
import glob
import iris
input_filepaths = glob.glob("../../../../derived_data/60km/rcp85/01/pr/day/pr_rcp85_land-gcm_uk_60km_01_day_19801201-19811130.nc")

# %%
example_input_cube = iris.load_cube(input_filepaths[0])
# Out:
# /home/henry/anaconda3/envs/downscaling/lib/python3.9/site-packages/iris/fileformats/cf.py:1156: UserWarning: Ignoring variable 'projection_y_coordinate_bnds' referenced by variable 'projection_y_coordinate': Dimensions ('time', 'projection_y_coordinate', 'bnds') do not span ('projection_y_coordinate',)
#   warnings.warn(msg)
# /home/henry/anaconda3/envs/downscaling/lib/python3.9/site-packages/iris/fileformats/cf.py:1156: UserWarning: Ignoring variable 'projection_x_coordinate_bnds' referenced by variable 'projection_x_coordinate': Dimensions ('time', 'projection_x_coordinate', 'bnds') do not span ('projection_x_coordinate',)
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# ~/anaconda3/envs/downscaling/lib/python3.9/site-packages/iris/__init__.py in load_cube(uris, constraint, callback)
#     336     try:
# --> 337         cube = cubes.merge_cube()
# ...
